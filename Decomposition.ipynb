# %%
from sklearn.datasets import load_digits
import matplotlib.pyplot as plt

# Load dataset
data = load_digits()
X = data.data
y = data.target

# Display an example image from the dataset
plt.imshow(data.images[0], cmap='gray')
plt.title(f"Label: {y[0]}")
plt.show()

# %%
# Out:
# 64

# %%
from sklearn.decomposition import PCA

# Apply PCA to reduce to 2 components for visualization
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# Plot the result
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis', edgecolor='k', s=40)
plt.title("PCA: Digits Dataset (2D Projection)")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.colorbar(label='Digit Label')
plt.show()
print("Dimension Before PCA",len(X[0]))
print("Dimension After PCA",len(X_pca[0]))
# Out:
# Dimension Before PCA 64
# Dimension After PCA 2
